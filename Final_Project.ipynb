# %% [markdown]
# <a href="https://colab.research.google.com/github/VyshnavipriyaChintapalli/Practice/blob/me/Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
      print(os.path.join(dirname, filename))

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df1 = pd.read_csv("/content/Fake Postings.csv")

# %%
df1
# Out:
#                                              title  \
# 0                              Mental health nurse
# 1                        Conference centre manager
# 2                                   Engineer, land
# 3                          Forest/woodland manager
# 4     Production designer, theatre/television/film
# ...                                            ...
# 9995                           Designer, furniture
# 9996                Therapist, speech and language
# 9997                             Therapist, sports
# 9998                   Clinical research associate
# 9999                           Hospital pharmacist
#
#                                             description  \
# 0     Arm drive court sure vote. Earn $5000/week! Im...
# 1     Government whom its bed go tax tree black. Ear...
# 2     I member discuss follow way there nation. Earn...
# 3     House across wait approach face. Earn $5000/we...
# 4     Case best environmental full finally leader me...
# ...

# %%
df2 = pd.read_csv("/content/fake_job_postings.csv")

# %%
df2
# Out:
#        job_id                                              title  \
# 0           1                                   Marketing Intern
# 1           2          Customer Service - Cloud Video Production
# 2           3            Commissioning Machinery Assistant (CMA)
# 3           4                  Account Executive - Washington DC
# 4           5                                Bill Review Manager
# ...       ...                                                ...
# 17875   17876                   Account Director - Distribution
# 17876   17877                                 Payroll Accountant
# 17877   17878  Project Cost Control Staff Engineer - Cost Con...
# 17878   17879                                   Graphic Designer
# 17879   17880                         Web Application Developers
#
#                    location   department salary_range  \
# 0          US, NY, New York    Marketing          NaN
# 1            NZ, , Auckland      Success          NaN
# ...

# %%
df1.columns
# Out:
# Index(['title', 'description', 'requirements', 'company_profile', 'location',
#        'salary_range', 'employment_type', 'industry', 'benefits',
#        'fraudulent'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['job_id', 'title', 'location', 'department', 'salary_range',
#        'company_profile', 'description', 'requirements', 'benefits',
#        'telecommuting', 'has_company_logo', 'has_questions', 'employment_type',
#        'required_experience', 'required_education', 'industry', 'function',
#        'fraudulent'],
#       dtype='object')

# %%
df_merged = pd.concat([df1, df2], ignore_index=True)

# %%
df_merged
# Out:
#                                                    title  \
# 0                                    Mental health nurse
# 1                              Conference centre manager
# 2                                         Engineer, land
# 3                                Forest/woodland manager
# 4           Production designer, theatre/television/film
# ...                                                  ...
# 27875                   Account Director - Distribution
# 27876                                 Payroll Accountant
# 27877  Project Cost Control Staff Engineer - Cost Con...
# 27878                                   Graphic Designer
# 27879                         Web Application Developers
#
#                                              description  \
# 0      Arm drive court sure vote. Earn $5000/week! Im...
# 1      Government whom its bed go tax tree black. Ear...
# 2      I member discuss follow way there nation. Earn...
# ...

# %%
df_merged.head()
# Out:
#                                           title  \
# 0                           Mental health nurse
# 1                     Conference centre manager
# 2                                Engineer, land
# 3                       Forest/woodland manager
# 4  Production designer, theatre/television/film
#
#                                          description  \
# 0  Arm drive court sure vote. Earn $5000/week! Im...
# 1  Government whom its bed go tax tree black. Ear...
# 2  I member discuss follow way there nation. Earn...
# 3  House across wait approach face. Earn $5000/we...
# 4  Case best environmental full finally leader me...
#
#                                         requirements  \
# 0  Basic knowledge in live, no degree required. F...
# 1  Basic knowledge in seek, no degree required. F...
# 2  Basic knowledge in worker, no degree required....
# 3  Basic knowledge in example, no degree required...
# 4  Basic knowledge in smile, no degree required. ...
#
# ...

# %%
df_merged.tail()
# Out:
#                                                    title  \
# 27875                   Account Director - Distribution
# 27876                                 Payroll Accountant
# 27877  Project Cost Control Staff Engineer - Cost Con...
# 27878                                   Graphic Designer
# 27879                         Web Application Developers
#
#                                              description  \
# 27875  Just in case this is the first time you’ve vis...
# 27876  The Payroll Accountant will focus primarily on...
# 27877  Experienced Project Cost Control Staff Enginee...
# 27878  Nemsia Studios is looking for an experienced v...
# 27879  Who are we?Vend is an award winning web based ...
#
#                                             requirements  \
# 27875  To ace this role you:Will eat comprehensive St...
# 27876  - B.A. or B.S. in Accounting- Desire to have f...
# 27877  At least 12 years professional experience.Abil...
# ...

# %%
df_merged.columns
# Out:
# Index(['title', 'description', 'requirements', 'company_profile', 'location',
#        'salary_range', 'employment_type', 'industry', 'benefits', 'fraudulent',
#        'job_id', 'department', 'telecommuting', 'has_company_logo',
#        'has_questions', 'required_experience', 'required_education',
#        'function'],
#       dtype='object')

# %%
df_merged = df_merged.drop(['job_id' , 'title', 'location', 'department', 'salary_range', 'telecommuting', 'has_company_logo', 'has_questions', 'employment_type','required_experience', 'required_education', 'industry', 'function'], axis=1)

# %%
df_merged
# Out:
#                                              description  \
# 0      Arm drive court sure vote. Earn $5000/week! Im...
# 1      Government whom its bed go tax tree black. Ear...
# 2      I member discuss follow way there nation. Earn...
# 3      House across wait approach face. Earn $5000/we...
# 4      Case best environmental full finally leader me...
# ...                                                  ...
# 27875  Just in case this is the first time you’ve vis...
# 27876  The Payroll Accountant will focus primarily on...
# 27877  Experienced Project Cost Control Staff Enginee...
# 27878  Nemsia Studios is looking for an experienced v...
# 27879  Who are we?Vend is an award winning web based ...
#
#                                             requirements  \
# 0      Basic knowledge in live, no degree required. F...
# 1      Basic knowledge in seek, no degree required. F...
# 2      Basic knowledge in worker, no degree required....
# ...

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27880 entries, 0 to 27879
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   description      27879 non-null  object
#  1   requirements     25184 non-null  object
#  2   company_profile  24572 non-null  object
#  3   benefits         20668 non-null  object
#  4   fraudulent       27880 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 1.1+ MB

# %%
df_merged = df_merged.fillna(" ")

# %%
df_merged['description'] = df_merged['description'] + " " + df_merged['company_profile'] + " "+ df_merged['requirements'] + " " +df_merged['benefits']

# %%
df_merged.head()
# Out:
#                                          description  \
# 0  Arm drive court sure vote. Earn $5000/week! Im...
# 1  Government whom its bed go tax tree black. Ear...
# 2  I member discuss follow way there nation. Earn...
# 3  House across wait approach face. Earn $5000/we...
# 4  Case best environmental full finally leader me...
#
#                                         requirements  \
# 0  Basic knowledge in live, no degree required. F...
# 1  Basic knowledge in seek, no degree required. F...
# 2  Basic knowledge in worker, no degree required....
# 3  Basic knowledge in example, no degree required...
# 4  Basic knowledge in smile, no degree required. ...
#
#                                     company_profile        benefits  \
# 0               Rivera and Sons - Established 2022.      Free meals
# 1     Davidson, Jones and Gomez - Established 2003.  Flexible hours
# 2                     Allen Ltd - Established 1998.     Free travel
# ...

# %%
df_merged.tail()
# Out:
#                                              description  \
# 27875  Just in case this is the first time you’ve vis...
# 27876  The Payroll Accountant will focus primarily on...
# 27877  Experienced Project Cost Control Staff Enginee...
# 27878  Nemsia Studios is looking for an experienced v...
# 27879  Who are we?Vend is an award winning web based ...
#
#                                             requirements  \
# 27875  To ace this role you:Will eat comprehensive St...
# 27876  - B.A. or B.S. in Accounting- Desire to have f...
# 27877  At least 12 years professional experience.Abil...
# 27878  1. Must be fluent in the latest versions of Co...
# 27879  We want to hear from you if:You have an in-dep...
#
#                                          company_profile  \
# 27875  Vend is looking for some awesome new talent to...
# 27876  WebLinc is the e-commerce platform and service...
# 27877  We Provide Full Time Permanent Positions for m...
# 27878
# ...

# %%
df_merged.columns
# Out:
# Index(['description', 'requirements', 'company_profile', 'benefits',
#        'fraudulent'],
#       dtype='object')

# %%
df_merged = df_merged.drop(['company_profile', 'requirements','benefits'], axis=1)

# %%
df_merged
# Out:
#                                              description  fraudulent
# 0      Arm drive court sure vote. Earn $5000/week! Im...           1
# 1      Government whom its bed go tax tree black. Ear...           1
# 2      I member discuss follow way there nation. Earn...           1
# 3      House across wait approach face. Earn $5000/we...           1
# 4      Case best environmental full finally leader me...           1
# ...                                                  ...         ...
# 27875  Just in case this is the first time you’ve vis...           0
# 27876  The Payroll Accountant will focus primarily on...           0
# 27877  Experienced Project Cost Control Staff Enginee...           0
# 27878  Nemsia Studios is looking for an experienced v...           0
# 27879  Who are we?Vend is an award winning web based ...           0
#
# [27880 rows x 2 columns]

# %%
tfidf_vectorizer = TfidfVectorizer(max_features=5000)

# %%
df_merged.fraudulent.value_counts()
# Out:
# fraudulent
# 0    17014
# 1    10866
# Name: count, dtype: int64

# %%
df_merged.columns
# Out:
# Index(['description', 'fraudulent'], dtype='object')

# %%
x = tfidf_vectorizer.fit_transform(df_merged['description'])
y = df_merged['fraudulent']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.1, random_state=20)

# %%
from sklearn.utils.class_weight import compute_class_weight
class_weights = compute_class_weight(class_weight = "balanced" , classes = np.unique(y_train), y = y_train)
class_weights_dict = dict(zip(np.unique(y_train), class_weights))

# %%
svm_model = SVC(kernel='linear', C=2, random_state=20)
svm_model.fit(x_train, y_train)
# Out:
# SVC(C=2, kernel='linear', random_state=20)

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score

# Define the model using hinge loss (equivalent to SVM)
svm_sgd = SGDClassifier(loss='hinge', learning_rate='optimal', random_state=20)

epochs = 3 # Define number of epochs
for epoch in range(epochs):
    svm_sgd.partial_fit(x_train, y_train, classes=[0, 1])  # Incremental learning
    train_accuracy = accuracy_score(y_train, svm_sgd.predict(x_train))
    print(f"Epoch {epoch + 1}/{epochs} - Training Accuracy: {train_accuracy:.4f}")

# Final evaluation on test set
test_accuracy = accuracy_score(y_test, svm_sgd.predict(x_test))
print(f"Final Test Accuracy: {test_accuracy:.4f}")
# Out:
# Epoch 1/3 - Training Accuracy: 0.9859
# Epoch 2/3 - Training Accuracy: 0.9863
# Epoch 3/3 - Training Accuracy: 0.9864
# Final Test Accuracy: 0.9839

# %%
y_pred = svm_model.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)

# %%
print("Accuracy:", accuracy)
print("\nClassification Report:\n", report)
print("\nConfusion Matrix:\n", confusion)
# Out:
# Accuracy: 0.9860114777618364
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1673
#            1       1.00      0.97      0.98      1115
#
#     accuracy                           0.99      2788
#    macro avg       0.99      0.98      0.99      2788
# weighted avg       0.99      0.99      0.99      2788
#
#
# Confusion Matrix:
#  [[1668    5]
#  [  34 1081]]

# %%
def job_post_detection():

    new_job_post = input("Enter the job description: ")

    # Put the new_job_post string inside a list to make it an iterable
    new_job_post_vectorized = tfidf_vectorizer.transform([new_job_post])
    prediction = svm_model.predict(new_job_post_vectorized)

    if prediction[0] == 1:
        print("\nThis job posting is predicted to be FAKE.")
    else:
        print("\nThis job posting is predicted to be REAL.")
job_post_detection()
# Out:
# Enter the job description: A job posting that offers a significantly higher salary than what's typical for the role and experience level is a major warning sign.
#
# This job posting is predicted to be REAL.
